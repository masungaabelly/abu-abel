# %%
import pandas as pd

df = pd.read_csv("land_conflict_data.csv")
df
# Out:
#    location  population_density  ownership_type  property_value  \
# 0         1                 200               1          150000
# 1         2                  80               2           80000
# 2         3                 300               1          200000
# 3         1                 250               2          120000
# 4         2                 100               1           90000
# 5         3                 400               1          300000
# 6         1                 150               2          100000
# 7         3                 350               1          180000
#
#    conflict_history  current_conflict
# 0                 2                 1
# 1                 0                 0
# 2                 3                 1
# 3                 1                 1
# 4                 1                 0
# 5                 4                 1
# 6                 1                 0
# 7                 3                 1

# %%
from sklearn.model_selection import train_test_split

X = df.drop("current_conflict", axis=1)
y = df["current_conflict"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
import joblib
joblib.dump(model, "land_conflict_model.pkl")
# Out:
# ['land_conflict_model.pkl']
